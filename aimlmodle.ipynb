# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
students_performance = {
    "Hours of Study": {
        "Maharshi": 20, "Jay": 15, "Sandeep": 25, "Malay": 18, "jamnejay": 12, 
        "Dhrumil": 22, "Het": 16, "Kathan": 28, "yash": 14, "anaconda": 19, 
        "bhoomi": 23, "kashish": 10, "purva": 30, "krupa": 11, "Sakshi": 24, 
        "pranshi": 17, "Srushti": 13, "Shelja": 26, "Khushi": 21, "Yogi": 9
    },
    "Books Read": {
        "Maharshi": 5, "Jay": 3, "Sandeep": 6, "Malay": 4, "jamnejay": 2, 
        "Dhrumil": 5, "Het": 3, "Kathan": 7, "yash": 3, "anaconda": 4, 
        "bhoomi": 6, "kashish": 1, "purva": 8, "krupa": 2, "Sakshi": 5, 
        "pranshi": 4, "Srushti": 3, "Shelja": 6, "Khushi": 5, "Yogi": 1
    },
    "Attendance": {
        "Maharshi": 90, "Jay": 85, "Sandeep": 95, "Malay": 88, "jamnejay": 80, 
        "Dhrumil": 92, "Het": 86, "Kathan": 98, "yash": 84, "anaconda": 89, 
        "bhoomi": 93, "kashish": 75, "purva": 99, "krupa": 78, "Sakshi": 94, 
        "pranshi": 87, "Srushti": 82, "Shelja": 96, "Khushi": 91, "Yogi": 73
    },
    "Current CGPA": {
        "Maharshi": 8.5, "Jay": 7.8, "Sandeep": 9.0, "Malay": 8.2, "jamnejay": 7.0, 
        "Dhrumil": 8.7, "Het": 7.9, "Kathan": 9.3, "yash": 7.5, "anaconda": 8.4, 
        "bhoomi": 8.8, "kashish": 6.5, "purva": 9.5, "krupa": 6.8, "Sakshi": 8.9, 
        "pranshi": 8.0, "Srushti": 7.2, "Shelja": 9.1, "Khushi": 8.6, "Yogi": 6.2
    },
    "Past CGPA": {
        "Maharshi": 8.0, "Jay": 7.5, "Sandeep": 8.7, "Malay": 7.9, "jamnejay": 6.8, 
        "Dhrumil": 8.3, "Het": 7.6, "Kathan": 9.0, "yash": 7.2, "anaconda": 8.1, 
        "bhoomi": 8.5, "kashish": 6.3, "purva": 9.2, "krupa": 6.6, "Sakshi": 8.6, 
        "pranshi": 7.7, "Srushti": 7.0, "Shelja": 8.8, "Khushi": 8.2, "Yogi": 6.0
    }
}

student_df = pd.DataFrame(students_performance)
student_df
# Out:
#           Hours of Study  Books Read  Attendance  Current CGPA  Past CGPA
# Maharshi              20           5          90           8.5        8.0
# Jay                   15           3          85           7.8        7.5
# Sandeep               25           6          95           9.0        8.7
# Malay                 18           4          88           8.2        7.9
# jamnejay              12           2          80           7.0        6.8
# Dhrumil               22           5          92           8.7        8.3
# Het                   16           3          86           7.9        7.6
# Kathan                28           7          98           9.3        9.0
# yash                  14           3          84           7.5        7.2
# anaconda              19           4          89           8.4        8.1
# bhoomi                23           6          93           8.8        8.5
# kashish               10           1          75           6.5        6.3
# ...

# %%
X = student_df[['Hours of Study']]
Y = student_df['Current CGPA']

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Create a Linear Regression model
model = LinearRegression()
# Train the model
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict([[5]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(Y_pred)
# Out:
# [5.94986099]
